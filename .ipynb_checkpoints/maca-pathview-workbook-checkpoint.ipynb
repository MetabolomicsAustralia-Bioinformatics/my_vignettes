# %% [markdown]
# # Pathway Analysis Pipeline
#
# ### Intro
#
# * This is the `R` version of the `pathview` webapp.
# * `pathview` colours nodes on KEGG network diagrams, based on input
#
# ### Review
# * **Pros**: `pathviewR` grants access to sanitized `KEGG` pathways. That's a *very* big pro.
# * **Cons**: More than the pros, unfortunately:
#     * I'm *still* not sure whether the input is logFC or abundance values. Some playing around with very simple 2-class examples has revealed that this doesn't make a difference.
#     * `GAGE` (automatic pathway selection functionality, which is presumably a pathway enrichment analysis method of some kind) has questionable efficacy. It appears to need many, many features (a test dataset with ~70 features yielded output pathways, but no output `.tsv` table with the associated q-values and statistics values).
# * Suggested usage: use the **joint pathway (enrichment) analysis** module on `MetaboAnalyst` to retrieve perturbed pathways, then visualize these with `pathview`.

# %%
# Load library and example datasets
library("pacman")

pacman::p_load("pathview", "gage", "tidyverse", "MetaboAnalystR", "KEGGREST", "httr")
data(gse16873.d)
# Load human pathways data
data(paths.hsa)
# load demo pathway-related data, including 3 pathway ids and related plotting params
# this is in dictionary format
data(demo.paths)

source("~/maca-utils/maca-kegg-utils.R")

# %% [markdown]
# ## Get DE metabs
#
# To provide `pathviewR` with fold change data.

# %%
fn_auc_csv <- "test_dme_data.csv"
tbl0 <- call_maca_normalization(fn_auc_csv)
tbl0 <- get_de_metabs(tbl0, 0.01, "treatment", "control", 0.05)
# Out:
# [1] "MetaboAnalyst R objects initialized ..."
#  [1] "Successfully passed sanity check!"
#  [2] "Samples are not paired."
#  [3] "2 groups were detected in samples."
#  [4] "Only English letters, numbers, underscore, hyphen and forward slash (/) are allowed."
#  [5] "<font color=\"orange\">Other special characters or punctuations (if any) will be stripped off.</font>"
#  [6] "All data values are numeric."
#  [7] "A total of 2 (0.1%) missing values were detected."
#  [8] "<u>By default, these values will be replaced by a small value.</u>"
#  [9] "Click <b>Skip</b> button if you accept the default practice"
# [10] "Or click <b>Missing value imputation</b> to use other methods"
# Warning message:
# “Duplicated column names deduplicated: 'Alanylglycine' => 'Alanylglycine_1' [59]”
# [1] "MetaboAnalyst R objects initialized ..."
# [1] "Loaded files from MetaboAnalyst web-server."
# [1] "Loaded files from MetaboAnalyst web-server."
# [1] "Loaded files from MetaboAnalyst web-server."
# NULL

# %%
head(tbl0)
# Out:
#   Sample                          log2_fc      KEGG   HMDB        raw_p_val
# 1 Alanylglycine                   -0.099317851 undef  HMDB0006899 0.767106122
# 2 2-Methylcitric acid              0.005383113 undef  HMDB0000379 0.984630576
# 3 4-Hydroxyproline                -2.541111981 C01157 HMDB0000725 0.332612676
# 4 3,4-Dihydroxybenzeneacetic acid  1.058901884 C01161 HMDB0001336 0.553459759
# 5 Adenosine triphosphate           3.122137114 C00002 HMDB0000538 0.007198896
# 6 3-Methyladenine                 -0.674902678 C00913 HMDB0011600 0.498074864
#   adj_p_val fc_colour
# 1 0.9960022 #ACACAC
# 2 0.9960022 #ACACAC
# 3 0.9960022 #ACACAC
# 4 0.9960022 #ACACAC
# 5 0.9718510 #ACACAC
# 6 0.9960022 #ACACAC

# %% [markdown]
# ## Get enriched pathways from MACA

# %%
x <- call_maca_pw_analysis("test_dme_data.csv", "dme")
tbl1 <- x[[1]]
pw_dict <- x[[2]]
pw_names <- get_kegg_pw_ref_tbl("dme")

# Manually replace some pw_names
tbl1$pw_name[tbl1$pw_name=="Fatty acid elongation in mitochondria"] <- "Fatty acid elongation"
tbl1$pw_name[tbl1$pw_name=="Glycolysis or Gluconeogenesis"] <- "Glycolysis / Gluconeogenesis"

# Join pw enrichment output with pw IDs
tbl1 <- inner_join(tbl1, pw_names, by="pw_name")
# Out:
# [1] "MetaboAnalyst R objects initialized ..."
# [1] "Loaded files from MetaboAnalyst web-server."
# [1] "Loaded files from MetaboAnalyst web-server."
# [1] "Loaded files from MetaboAnalyst web-server."
#  [1] "Successfully passed sanity check!"
#  [2] "Samples are not paired."
#  [3] "2 groups were detected in samples."
#  [4] "Only English letters, numbers, underscore, hyphen and forward slash (/) are allowed."
#  [5] "<font color=\"orange\">Other special characters or punctuations (if any) will be stripped off.</font>"
#  [6] "All data values are numeric."
#  [7] "A total of 2 (0.1%) missing values were detected."
#  [8] "<u>By default, these values will be replaced by a small value.</u>"
#  [9] "Click <b>Skip</b> button if you accept the default practice"
# [10] "Or click <b>Missing value imputation</b> to use other methods"
# [1] "Loaded files from MetaboAnalyst web-server."

# %%
tbl1
# Out:
#    pw_name                                             Total Cmpd Hits
# 1  Aminoacyl-tRNA biosynthesis                         67         19
# 2  Sphingolipid metabolism                             18          1
# 3  Taurine and hypotaurine metabolism                   6          1
# 4  Alanine, aspartate and glutamate metabolism         23         13
# 5  Histidine metabolism                                 7          3
# 6  Thiamine metabolism                                  6          1
# 7  Purine metabolism                                   64         16
# 8  Nitrogen metabolism                                  7          3
# 9  Starch and sucrose metabolism                       17          8
# 10 Cysteine and methionine metabolism                  25          7
# 11 beta-Alanine metabolism                             13          2
# 12 Porphyrin and chlorophyll metabolism                23          3
# 13 Pantothenate and CoA biosynthesis                   12          3
# 14 Valine, leucine and isoleucine biosynthesis         13          6
# 15 Ubiquinone and other terpenoid-quinone biosynthesis  3          2
# 16 Phenylalanine, tyrosine and tryptophan biosynthesis  4          3
# 17 N-Glycan biosynthesis                               35          1
# 18 Valine, leucine and isoleucine degradation          35          7
# 19 Ascorbate and aldarate metabolism                    6          3
# 20 Vitamin B6 metabolism                                8          1
# 21 Pyrimidine metabolism                               41         12
# 22 Butanoate metabolism                                21          9
# 23 Pyruvate metabolism                                 24          6
# 24 Pentose and glucuronate interconversions            14          4
# 25 Galactose metabolism                                26          9
# 26 D-Glutamine and D-glutamate metabolism               5          3
# 27 Glycolysis / Gluconeogenesis                        25          6
# 28 Citrate cycle (TCA cycle)                           20         11
# 29 Biotin metabolism                                    5          2
# 30 Fructose and mannose metabolism                     18          3
# 31 Glycerophospholipid metabolism                      27          3
# 32 Fatty acid biosynthesis                             38          3
# 33 Inositol phosphate metabolism                       24          4
# 34 Amino sugar and nucleotide sugar metabolism         34          9
# 35 Pentose phosphate pathway                           19          7
# 36 Glutathione metabolism                              26          5
# 37 Glycerolipid metabolism                             16          2
# 38 Arginine and proline metabolism                     37         11
# 39 Glycine, serine and threonine metabolism            25          7
# 40 Riboflavin metabolism                                7          2
# 41 Tyrosine metabolism                                 30          5
# 42 Fatty acid metabolism                               38          3
# 43 Phenylalanine metabolism                            10          3
# 44 Glyoxylate and dicarboxylate metabolism             16          7
# 45 Propanoate metabolism                               18          4
# 46 Fatty acid elongation                               27          2
# 47 Tryptophan metabolism                               23          3
# 48 Lysine degradation                                  17          2
# 49 Nicotinate and nicotinamide metabolism               9          3
# 50 Terpenoid backbone biosynthesis                     13          1
# 51 Synthesis and degradation of ketone bodies           5          2
#    Raw p      -log(p)  Holm adjust FDR        Impact  pw_id
# 1  1.5215e-08 18.00100 8.0641e-07  8.0641e-07 0.13793 dme00970
# 2  3.2116e-06 12.64900 1.6700e-04  8.5108e-05 0.00000 dme00600
# 3  2.1607e-05 10.74200 1.0587e-03  2.2903e-04 0.50000 dme00430
# 4  1.6563e-04  8.70580 7.9502e-03  1.4631e-03 0.95947 dme00250
# 5  2.9965e-04  8.11290 1.4083e-02  2.2688e-03 1.00000 dme00340
# 6  4.0804e-04  7.80420 1.8770e-02  2.7032e-03 0.50000 dme00730
# 7  5.3155e-04  7.53970 2.3920e-02  3.0268e-03 0.32899 dme00230
# 8  5.7110e-04  7.46790 2.5128e-02  3.0268e-03 0.00000 dme00910
# 9  3.0296e-03  5.79930 1.3027e-01  1.4228e-02 0.40631 dme00500
# 10 3.2214e-03  5.73790 1.3530e-01  1.4228e-02 0.23891 dme00270
# 11 4.3606e-03  5.43510 1.7879e-01  1.7778e-02 0.41379 dme00410
# 12 5.8205e-03  5.14640 2.3282e-01  2.2035e-02 0.04472 dme00860
# 13 8.2449e-03  4.79820 3.2155e-01  2.9132e-02 0.00000 dme00770
# 14 9.4534e-03  4.66140 3.5923e-01  2.9667e-02 0.99999 dme00290
# 15 9.5157e-03  4.65480 3.5923e-01  2.9667e-02 1.00000 dme00130
# 16 1.0177e-02  4.58760 3.6637e-01  2.9965e-02 1.00000 dme00400
# 17 1.1356e-02  4.47800 3.9745e-01  3.1677e-02 0.00000 dme00510
# 18 1.4859e-02  4.20910 5.0522e-01  3.9377e-02 0.07973 dme00280
# 19 2.1497e-02  3.83990 7.0939e-01  5.1513e-02 0.50000 dme00053
# 20 2.2750e-02  3.78320 7.2800e-01  5.1513e-02 0.33333 dme00750
# 21 2.2881e-02  3.77740 7.2800e-01  5.1513e-02 0.46750 dme00240
# 22 2.3327e-02  3.75820 7.2800e-01  5.1513e-02 0.63637 dme00650
# 23 2.6030e-02  3.64850 7.5488e-01  5.5184e-02 0.37767 dme00620
# 24 3.0900e-02  3.47700 8.6521e-01  6.2989e-02 0.27273 dme00040
# 25 4.3680e-02  3.13090 1.0000e+00  8.5742e-02 0.13673 dme00052
# 26 6.4668e-02  2.73850 1.0000e+00  1.2241e-01 1.00000 dme00471
# 27 7.7227e-02  2.56100 1.0000e+00  1.4114e-01 0.17835 dme00010
# 28 9.4779e-02  2.35620 1.0000e+00  1.6744e-01 0.55588 dme00020
# 29 1.1041e-01  2.20350 1.0000e+00  1.8877e-01 0.40000 dme00780
# 30 1.1614e-01  2.15300 1.0000e+00  1.9236e-01 0.14317 dme00051
# 31 1.3266e-01  2.01990 1.0000e+00  2.1307e-01 0.09761 dme00564
# 32 1.4383e-01  1.93910 1.0000e+00  2.2421e-01 0.02717 dme00061
# 33 1.6501e-01  1.80170 1.0000e+00  2.4349e-01 0.20430 dme00562
# 34 1.6939e-01  1.77560 1.0000e+00  2.4349e-01 0.29294 dme00520
# 35 1.7335e-01  1.75240 1.0000e+00  2.4349e-01 0.48048 dme00030
# 36 1.7458e-01  1.74540 1.0000e+00  2.4349e-01 0.47940 dme00480
# 37 1.7978e-01  1.71600 1.0000e+00  2.4432e-01 0.27443 dme00561
# 38 2.0235e-01  1.59770 1.0000e+00  2.6812e-01 0.52812 dme00330
# 39 2.4782e-01  1.39510 1.0000e+00  3.1639e-01 0.57079 dme00260
# 40 2.5072e-01  1.38340 1.0000e+00  3.1639e-01 0.33333 dme00740
# 41 3.2648e-01  1.11940 1.0000e+00  4.0241e-01 0.36144 dme00350
# 42 4.5744e-01  0.78212 1.0000e+00  5.5100e-01 0.25512 dme01212
# 43 4.6901e-01  0.75712 1.0000e+00  5.5240e-01 0.69231 dme00360
# 44 5.2563e-01  0.64315 1.0000e+00  6.0562e-01 0.66667 dme00630
# 45 5.4138e-01  0.61363 1.0000e+00  6.1050e-01 0.03333 dme00640
# 46 5.7452e-01  0.55421 1.0000e+00  6.3437e-01 0.25220 dme00062
# 47 6.1634e-01  0.48396 1.0000e+00  6.6665e-01 0.37500 dme00380
# 48 6.8312e-01  0.38109 1.0000e+00  7.2411e-01 0.00000 dme00310
# 49 7.0446e-01  0.35032 1.0000e+00  7.3209e-01 0.29231 dme00760
# 50 7.2385e-01  0.32317 1.0000e+00  7.3302e-01 0.00000 dme00900
# 51 7.3302e-01  0.31059 1.0000e+00  7.3302e-01 0.60000 dme00072

# %%
pw_name_ls0 <- as.vector(unlist(tbl0["pw_name"]))
pw_name_ls1 <- as.vector(unlist(tbl1["pw_name"]))

for (pw in pw_name_ls0) {
    if (pw %in% pw_name_ls1 == F) {
        print(pw)
    }
}

# %% [markdown]
# ## Call PathviewR
#
# * Use `pathviewR` to retrieve the sanitized KEGG graphs (which it claims to be able to). As it turns out, it can do these in `.png` format, but not the editable `.xml` format.
# * Also do data mapping, with a single named list of logFC values (names are KEGG Ids). But these will only result in coloured nodes; barcharts are better.
# * Will return a lot of `pngs` and `xmls`.

# %%
# Get input compound data
# named list of logFCs, names are KEGG Id
tbl_tmp <- tbl0 %>% dplyr::select(c("KEGG", "log2_fc")) %>% filter(KEGG != "undef")
cpd_data_ls <- unlist(tbl_tmp$log2_fc)
names(cpd_data_ls) <- unlist(tbl_tmp$KEGG)

# Get list of pathway numbers
pw_num_ls <- lapply(unlist(tbl1$pw_id), function(x) {gsub("dme", "", x)})

# %%
i <- 1
suffix_i <- paste0("dme", pw_num_ls[i])
pathview(cpd.data = cpd_data_ls,
         pathway.id = pw_num_ls[i], 
         species = "dme", 
         out.suffix = suffix_i,
         keys.align = "y", 
         kegg.native = T
         )

# %% [markdown]
# ## Get `kgml` from KEGG APIs
#
# * This kind of works, but won't give sanitized xml pathway maps to modify. The example below (Aminoacyl-tRNA Biosynthesis) is one such instance.

# %%
pw_num_ls[1]

r <- GET("http://rest.kegg.jp/get/dme00970/kgml")
print(status_code(r))

# %%
writeLines(x0_text, file("test.svg"))

# %%
# Write out
xml_main <- content(r, "text")
x0_text <- strsplit(xml_main, "\n")[[1]] # to modify
write(xml_main, "dme-test1.kgml")
